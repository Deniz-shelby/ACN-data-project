# %%
import pandas as pd

# %%
df = pd.read_csv('df_sum.csv')

# %%
df
# Out:
#       Unnamed: 0                  zeitreihe  sum_parked_count  sum_kWh_count  \
# 0              0  2019-04-01 00:00:00-07:00                 1          23.52
# 1              1  2019-04-01 00:15:00-07:00                 1          24.77
# 2              2  2019-04-01 00:30:00-07:00                 1          26.02
# 3              3  2019-04-01 00:45:00-07:00                 1          27.27
# 4              4  2019-04-01 01:00:00-07:00                 1          28.52
# ...          ...                        ...               ...            ...
# 5852        5852  2019-05-31 23:00:00-07:00                 4          77.20
# 5853        5853  2019-05-31 23:15:00-07:00                 4          79.28
# 5854        5854  2019-05-31 23:30:00-07:00                 4          81.36
# 5855        5855  2019-05-31 23:45:00-07:00                 4          83.44
# 5856        5856  2019-06-01 00:00:00-07:00                 4          85.52
#
#       sum_kWh_potential
# ...
